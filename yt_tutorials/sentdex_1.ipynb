# %%
import gymnasium as gym
from stable_baselines3.a2c import A2C

# %%
env = gym.make("LunarLander-v2",render_mode="human")

# %%
env.reset()
for step in range(200):
    env.render()
    obs,reward,done,truncated,info = env.step(env.action_space.sample())

env.close()
# Out:
# El Kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior. Revise el código de las celdas para identificar una posible causa del error. Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información. Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
env.reset()
model = A2C("MlpPolicy",env,verbose=1)
model.learn(100_000)

episodes = 10

for ep in range(episodes):
    obs = env.reset()
    done = False
    while not done:
        env.render("human")
        obs,reward,done,truncated,info = env.step(env.action_space.sample())

env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 124      |
# |    ep_rew_mean        | -358     |
# | time/                 |          |
# |    fps                | 2608     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.21    |
# |    explained_variance | 0.0458   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -16.3    |
# |    value_loss         | 509      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 123      |
# |    ep_rew_mean        | -290     |
# | time/                 |          |
# |    fps                | 2901     |
# |    iterations         | 200      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.0382   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.956    |
# |    value_loss         | 1.45     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 125      |
# |    ep_rew_mean        | -391     |
# | time/                 |          |
# |    fps                | 3009     |
# |    iterations         | 300      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.735   |
# |    explained_variance | 0.000669 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -6.73    |
# |    value_loss         | 1.01e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 122      |
# |    ep_rew_mean        | -457     |
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 400      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.2     |
# |    explained_variance | -0.00174 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -4.36    |
# |    value_loss         | 30       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 121      |
# |    ep_rew_mean        | -453     |
# | time/                 |          |
# |    fps                | 3096     |
# |    iterations         | 500      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -0.00742 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 3.97     |
# |    value_loss         | 19.3     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 127       |
# |    ep_rew_mean        | -435      |
# | time/                 |           |
# |    fps                | 3122      |
# |    iterations         | 600       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -1.22     |
# |    explained_variance | -0.000199 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -2.48     |
# |    value_loss         | 8.77      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 135      |
# |    ep_rew_mean        | -406     |
# | time/                 |          |
# |    fps                | 3137     |
# |    iterations         | 700      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.794   |
# |    explained_variance | 0.0266   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -14.1    |
# |    value_loss         | 490      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 137      |
# |    ep_rew_mean        | -392     |
# | time/                 |          |
# |    fps                | 3151     |
# |    iterations         | 800      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.802   |
# |    explained_variance | -0.00676 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 2.21     |
# |    value_loss         | 26.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 137      |
# |    ep_rew_mean        | -392     |
# | time/                 |          |
# |    fps                | 3155     |
# |    iterations         | 900      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | 0.0336   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.192    |
# |    value_loss         | 0.133    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 166      |
# |    ep_rew_mean        | -369     |
# | time/                 |          |
# |    fps                | 3154     |
# |    iterations         | 1000     |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.779   |
# |    explained_variance | 0.00129  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -1.2     |
# |    value_loss         | 11.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 165      |
# |    ep_rew_mean        | -344     |
# | time/                 |          |
# |    fps                | 3151     |
# |    iterations         | 1100     |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.00132  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 1.55     |
# |    value_loss         | 1.69     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 169      |
# |    ep_rew_mean        | -340     |
# | time/                 |          |
# |    fps                | 3161     |
# |    iterations         | 1200     |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.538   |
# |    explained_variance | 0.0117   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -2.48    |
# |    value_loss         | 41.2     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 173       |
# |    ep_rew_mean        | -322      |
# | time/                 |           |
# |    fps                | 3168      |
# |    iterations         | 1300      |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.832    |
# |    explained_variance | -0.000255 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 2.37      |
# |    value_loss         | 13.9      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 181      |
# |    ep_rew_mean        | -308     |
# | time/                 |          |
# |    fps                | 3177     |
# |    iterations         | 1400     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.862   |
# |    explained_variance | -0.00116 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -1.54    |
# |    value_loss         | 5.39     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 185      |
# |    ep_rew_mean        | -295     |
# | time/                 |          |
# |    fps                | 3181     |
# |    iterations         | 1500     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.411   |
# |    explained_variance | -0.837   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -5.18    |
# |    value_loss         | 12       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 185      |
# |    ep_rew_mean        | -283     |
# | time/                 |          |
# |    fps                | 3185     |
# |    iterations         | 1600     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.778   |
# |    explained_variance | 0.000728 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -2.5     |
# |    value_loss         | 22.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 188      |
# |    ep_rew_mean        | -276     |
# | time/                 |          |
# |    fps                | 3189     |
# |    iterations         | 1700     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -1.21    |
# |    explained_variance | 0.000872 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.416    |
# |    value_loss         | 7.49     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 188      |
# |    ep_rew_mean        | -276     |
# | time/                 |          |
# |    fps                | 3197     |
# |    iterations         | 1800     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.643   |
# |    explained_variance | 0.00884  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -2.23    |
# |    value_loss         | 16.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 198      |
# |    ep_rew_mean        | -271     |
# | time/                 |          |
# |    fps                | 3198     |
# |    iterations         | 1900     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.333   |
# |    explained_variance | 0.0722   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.626   |
# |    value_loss         | 46       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 199      |
# |    ep_rew_mean        | -265     |
# | time/                 |          |
# |    fps                | 3200     |
# |    iterations         | 2000     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.348   |
# |    explained_variance | -0.139   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 1.14     |
# |    value_loss         | 8.8      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | -253     |
# | time/                 |          |
# |    fps                | 3203     |
# |    iterations         | 2100     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.561   |
# |    explained_variance | -0.0354  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 2.87     |
# |    value_loss         | 57.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 203      |
# |    ep_rew_mean        | -245     |
# | time/                 |          |
# |    fps                | 3203     |
# |    iterations         | 2200     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.778   |
# |    explained_variance | 0.00555  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 1.99     |
# |    value_loss         | 6.52     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 207      |
# |    ep_rew_mean        | -246     |
# | time/                 |          |
# |    fps                | 3136     |
# |    iterations         | 2300     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.381   |
# |    explained_variance | -0.00637 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 2.63     |
# |    value_loss         | 140      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 207      |
# |    ep_rew_mean        | -243     |
# | time/                 |          |
# |    fps                | 3080     |
# |    iterations         | 2400     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.376   |
# |    explained_variance | 0.0247   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -5.25    |
# |    value_loss         | 54       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | -240     |
# | time/                 |          |
# |    fps                | 3079     |
# |    iterations         | 2500     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.606   |
# |    explained_variance | 0.18     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -5.74    |
# |    value_loss         | 147      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 211      |
# |    ep_rew_mean        | -241     |
# | time/                 |          |
# |    fps                | 3084     |
# |    iterations         | 2600     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.791   |
# |    explained_variance | -0.0336  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -4.21    |
# |    value_loss         | 29.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 212      |
# |    ep_rew_mean        | -233     |
# | time/                 |          |
# |    fps                | 3090     |
# |    iterations         | 2700     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.304   |
# |    explained_variance | -9.92    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.372    |
# |    value_loss         | 22.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 211      |
# |    ep_rew_mean        | -228     |
# | time/                 |          |
# |    fps                | 3093     |
# |    iterations         | 2800     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.795   |
# |    explained_variance | 0.000505 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -4.06    |
# |    value_loss         | 12.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 212      |
# |    ep_rew_mean        | -225     |
# | time/                 |          |
# |    fps                | 3099     |
# |    iterations         | 2900     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.679   |
# |    explained_variance | -0.0863  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.835    |
# |    value_loss         | 4.39     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 213      |
# |    ep_rew_mean        | -223     |
# | time/                 |          |
# |    fps                | 3098     |
# |    iterations         | 3000     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.318   |
# |    explained_variance | 0.127    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -7.1     |
# |    value_loss         | 51.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 213      |
# |    ep_rew_mean        | -221     |
# | time/                 |          |
# |    fps                | 3104     |
# |    iterations         | 3100     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | -0.408   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 7.65     |
# |    value_loss         | 244      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | -215     |
# | time/                 |          |
# |    fps                | 3109     |
# |    iterations         | 3200     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.888   |
# |    explained_variance | -0.00979 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -1.73    |
# |    value_loss         | 4.25     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 217      |
# |    ep_rew_mean        | -213     |
# | time/                 |          |
# |    fps                | 3113     |
# |    iterations         | 3300     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.343   |
# |    explained_variance | 0.0776   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 7.27     |
# |    value_loss         | 261      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 217      |
# |    ep_rew_mean        | -212     |
# | time/                 |          |
# |    fps                | 3119     |
# |    iterations         | 3400     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.76    |
# |    explained_variance | -0.021   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.364    |
# |    value_loss         | 24.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 217      |
# |    ep_rew_mean        | -211     |
# | time/                 |          |
# |    fps                | 3121     |
# |    iterations         | 3500     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.157   |
# |    explained_variance | -0.622   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.0536  |
# |    value_loss         | 3.88     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 218      |
# |    ep_rew_mean        | -209     |
# | time/                 |          |
# |    fps                | 3126     |
# |    iterations         | 3600     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.0913  |
# |    explained_variance | -0.0532  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -5.53    |
# |    value_loss         | 60.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 218      |
# |    ep_rew_mean        | -211     |
# | time/                 |          |
# |    fps                | 3132     |
# |    iterations         | 3700     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.344   |
# |    explained_variance | 0.0405   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -4.76    |
# |    value_loss         | 64.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | -206     |
# | time/                 |          |
# |    fps                | 3135     |
# |    iterations         | 3800     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.562   |
# |    explained_variance | 0.486    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.223   |
# |    value_loss         | 3.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 224      |
# |    ep_rew_mean        | -202     |
# | time/                 |          |
# |    fps                | 3139     |
# |    iterations         | 3900     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.00174 |
# |    explained_variance | 0.044    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.00155  |
# |    value_loss         | 136      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | -202     |
# | time/                 |          |
# |    fps                | 3143     |
# |    iterations         | 4000     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.399   |
# |    explained_variance | 0.258    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -1.49    |
# |    value_loss         | 123      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 226      |
# |    ep_rew_mean        | -200     |
# | time/                 |          |
# |    fps                | 3149     |
# |    iterations         | 4100     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.634   |
# |    explained_variance | -1.32    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.955    |
# |    value_loss         | 6.53     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 226      |
# |    ep_rew_mean        | -197     |
# | time/                 |          |
# |    fps                | 3153     |
# |    iterations         | 4200     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.101   |
# |    explained_variance | -0.794   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.0247   |
# |    value_loss         | 8.44     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | -193     |
# | time/                 |          |
# |    fps                | 3157     |
# |    iterations         | 4300     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.0214  |
# |    explained_variance | 0.626    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.00612 |
# |    value_loss         | 4.99     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 227      |
# |    ep_rew_mean        | -186     |
# | time/                 |          |
# |    fps                | 3159     |
# |    iterations         | 4400     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.015   |
# |    explained_variance | -0.142   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.0121   |
# |    value_loss         | 32.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 226      |
# |    ep_rew_mean        | -184     |
# | time/                 |          |
# |    fps                | 3163     |
# |    iterations         | 4500     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.567   |
# |    explained_variance | -1.41    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 2.35     |
# |    value_loss         | 37.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 228      |
# |    ep_rew_mean        | -186     |
# | time/                 |          |
# |    fps                | 3167     |
# |    iterations         | 4600     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.671   |
# |    explained_variance | -0.222   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 2.71     |
# |    value_loss         | 36.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 230      |
# |    ep_rew_mean        | -175     |
# | time/                 |          |
# |    fps                | 3172     |
# |    iterations         | 4700     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.615   |
# |    explained_variance | 0.172    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 1.64     |
# |    value_loss         | 9.53     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 233      |
# |    ep_rew_mean        | -168     |
# | time/                 |          |
# |    fps                | 3176     |
# |    iterations         | 4800     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.656   |
# |    explained_variance | -0.00481 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 7.43     |
# |    value_loss         | 211      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 235      |
# |    ep_rew_mean        | -165     |
# | time/                 |          |
# |    fps                | 3179     |
# |    iterations         | 4900     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.239   |
# |    explained_variance | -0.421   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 7.29     |
# |    value_loss         | 42       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 238      |
# |    ep_rew_mean        | -162     |
# | time/                 |          |
# |    fps                | 3182     |
# |    iterations         | 5000     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.586   |
# |    explained_variance | -25.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -4.2     |
# |    value_loss         | 235      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 240      |
# |    ep_rew_mean        | -152     |
# | time/                 |          |
# |    fps                | 3184     |
# |    iterations         | 5100     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.509   |
# |    explained_variance | 0.928    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.139   |
# |    value_loss         | 0.278    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 244      |
# |    ep_rew_mean        | -140     |
# | time/                 |          |
# |    fps                | 3187     |
# |    iterations         | 5200     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.638   |
# |    explained_variance | 0.328    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -4.48    |
# |    value_loss         | 48.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 247      |
# |    ep_rew_mean        | -128     |
# | time/                 |          |
# |    fps                | 3188     |
# |    iterations         | 5300     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -0.415   |
# |    explained_variance | -0.544   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.179   |
# |    value_loss         | 2.71     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 249      |
# |    ep_rew_mean        | -121     |
# | time/                 |          |
# |    fps                | 3189     |
# |    iterations         | 5400     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.19    |
# |    explained_variance | 0.309    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -2.73    |
# |    value_loss         | 13.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 253      |
# |    ep_rew_mean        | -112     |
# | time/                 |          |
# |    fps                | 3189     |
# |    iterations         | 5500     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.573   |
# |    explained_variance | -0.0703  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 2.39     |
# |    value_loss         | 21.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 255      |
# |    ep_rew_mean        | -104     |
# | time/                 |          |
# |    fps                | 3192     |
# |    iterations         | 5600     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.302   |
# |    explained_variance | -0.0612  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.911    |
# |    value_loss         | 4.56     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 255      |
# |    ep_rew_mean        | -104     |
# | time/                 |          |
# |    fps                | 3192     |
# |    iterations         | 5700     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.582   |
# |    explained_variance | 0.24     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.0831  |
# |    value_loss         | 0.0107   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 259      |
# |    ep_rew_mean        | -93.4    |
# | time/                 |          |
# |    fps                | 3194     |
# |    iterations         | 5800     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.53    |
# |    explained_variance | -10.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.689    |
# |    value_loss         | 9.08     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 260      |
# |    ep_rew_mean        | -94.2    |
# | time/                 |          |
# |    fps                | 3186     |
# |    iterations         | 5900     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.123   |
# |    explained_variance | 0.915    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.0034  |
# |    value_loss         | 0.302    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 261      |
# |    ep_rew_mean        | -90.5    |
# | time/                 |          |
# |    fps                | 3186     |
# |    iterations         | 6000     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.566   |
# |    explained_variance | 0.184    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -2.9     |
# |    value_loss         | 44       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 256      |
# |    ep_rew_mean        | -88.8    |
# | time/                 |          |
# |    fps                | 3188     |
# |    iterations         | 6100     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.409   |
# |    explained_variance | -2.59    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 1.12     |
# |    value_loss         | 22.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 257      |
# |    ep_rew_mean        | -87.4    |
# | time/                 |          |
# |    fps                | 3190     |
# |    iterations         | 6200     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -0.469   |
# |    explained_variance | 0.0941   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.344   |
# |    value_loss         | 4.36     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 261      |
# |    ep_rew_mean        | -84.7    |
# | time/                 |          |
# |    fps                | 3191     |
# |    iterations         | 6300     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.553   |
# |    explained_variance | 0.948    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.157    |
# |    value_loss         | 0.688    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 261      |
# |    ep_rew_mean        | -84.9    |
# | time/                 |          |
# |    fps                | 3193     |
# |    iterations         | 6400     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.665   |
# |    explained_variance | 0.142    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 0.827    |
# |    value_loss         | 2.87     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 261      |
# |    ep_rew_mean        | -82.6    |
# | time/                 |          |
# |    fps                | 3192     |
# |    iterations         | 6500     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.711   |
# |    explained_variance | -0.0861  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.0316  |
# |    value_loss         | 0.00438  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 265      |
# |    ep_rew_mean        | -80.1    |
# | time/                 |          |
# |    fps                | 3191     |
# |    iterations         | 6600     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.273   |
# |    explained_variance | 0.34     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -4.1     |
# |    value_loss         | 22.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 262      |
# |    ep_rew_mean        | -80.7    |
# | time/                 |          |
# |    fps                | 3192     |
# |    iterations         | 6700     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.00954 |
# |    explained_variance | -7.22    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.0206  |
# |    value_loss         | 149      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 265      |
# |    ep_rew_mean        | -79.9    |
# | time/                 |          |
# |    fps                | 3193     |
# |    iterations         | 6800     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.0251  |
# |    explained_variance | 0.0207   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.482    |
# |    value_loss         | 2.01e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 265      |
# |    ep_rew_mean        | -77.9    |
# | time/                 |          |
# |    fps                | 3194     |
# |    iterations         | 6900     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.631   |
# |    explained_variance | -0.0554  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.245   |
# |    value_loss         | 0.172    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 267      |
# |    ep_rew_mean        | -73.4    |
# | time/                 |          |
# |    fps                | 3195     |
# |    iterations         | 7000     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | -0.244   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 4.56     |
# |    value_loss         | 46.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 261      |
# |    ep_rew_mean        | -70.9    |
# | time/                 |          |
# |    fps                | 3196     |
# |    iterations         | 7100     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -0.221   |
# |    explained_variance | 0.555    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -3.85    |
# |    value_loss         | 30.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 259      |
# |    ep_rew_mean        | -70.9    |
# | time/                 |          |
# |    fps                | 3198     |
# |    iterations         | 7200     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.659   |
# |    explained_variance | 0.506    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 4.07     |
# |    value_loss         | 70.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 259      |
# |    ep_rew_mean        | -68.6    |
# | time/                 |          |
# |    fps                | 3200     |
# |    iterations         | 7300     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.305   |
# |    explained_variance | 0.904    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | -0.153   |
# |    value_loss         | 5.11     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 255       |
# |    ep_rew_mean        | -67.7     |
# | time/                 |           |
# |    fps                | 3201      |
# |    iterations         | 7400      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -0.000113 |
# |    explained_variance | 0.436     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -4.72e-06 |
# |    value_loss         | 1.06      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 254      |
# |    ep_rew_mean        | -65.4    |
# | time/                 |          |
# |    fps                | 3202     |
# |    iterations         | 7500     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.561   |
# |    explained_variance | 0.0688   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 4.34     |
# |    value_loss         | 49.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 253      |
# |    ep_rew_mean        | -62.5    |
# | time/                 |          |
# |    fps                | 3203     |
# |    iterations         | 7600     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.0859  |
# |    explained_variance | -6.49    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | -11.5    |
# |    value_loss         | 220      |
# ------------------------------------
# ------------------------------------
# ...
# | train/                |          |
# |    entropy_loss       | -0.286   |
# |    explained_variance | 0.687    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17699    |
# |    policy_loss        | -1.22    |
# |    value_loss         | 15.8     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 278       |
# |    ep_rew_mean        | 11.3      |
# | time/                 |           |
# |    fps                | 3218      |
# |    iterations         | 17800     |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 89000     |
# | train/                |           |
# |    entropy_loss       | -0.146    |
# |    explained_variance | -1.45e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17799     |
# |    policy_loss        | -0.00442  |
# |    value_loss         | 0.0239    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 273      |
# |    ep_rew_mean        | 11.5     |
# | time/                 |          |
# |    fps                | 3218     |
# |    iterations         | 17900    |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 89500    |
# | train/                |          |
# |    entropy_loss       | -0.968   |
# |    explained_variance | 0.902    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17899    |
# |    policy_loss        | -2.59    |
# |    value_loss         | 14.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 270      |
# |    ep_rew_mean        | 9.87     |
# | time/                 |          |
# |    fps                | 3218     |
# |    iterations         | 18000    |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.976   |
# |    explained_variance | 0.963    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17999    |
# |    policy_loss        | 0.104    |
# |    value_loss         | 0.135    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 276      |
# |    ep_rew_mean        | 11.5     |
# | time/                 |          |
# |    fps                | 3219     |
# |    iterations         | 18100    |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 90500    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0.544    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18099    |
# |    policy_loss        | -0.827   |
# |    value_loss         | 6.08     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 276      |
# |    ep_rew_mean        | 11.5     |
# | time/                 |          |
# |    fps                | 3219     |
# |    iterations         | 18200    |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 91000    |
# | train/                |          |
# |    entropy_loss       | -0.518   |
# |    explained_variance | 0.948    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18199    |
# |    policy_loss        | -0.254   |
# |    value_loss         | 0.62     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 283      |
# |    ep_rew_mean        | 12.1     |
# | time/                 |          |
# |    fps                | 3219     |
# |    iterations         | 18300    |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 91500    |
# | train/                |          |
# |    entropy_loss       | -0.648   |
# |    explained_variance | 0.973    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18299    |
# |    policy_loss        | -0.282   |
# |    value_loss         | 0.118    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 283      |
# |    ep_rew_mean        | 12.1     |
# | time/                 |          |
# |    fps                | 3220     |
# |    iterations         | 18400    |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.551   |
# |    explained_variance | 0.923    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18399    |
# |    policy_loss        | -0.388   |
# |    value_loss         | 0.369    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 290      |
# |    ep_rew_mean        | 15       |
# | time/                 |          |
# |    fps                | 3220     |
# |    iterations         | 18500    |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 92500    |
# | train/                |          |
# |    entropy_loss       | -0.915   |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18499    |
# |    policy_loss        | -0.022   |
# |    value_loss         | 0.0168   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 290      |
# |    ep_rew_mean        | 15       |
# | time/                 |          |
# |    fps                | 3220     |
# |    iterations         | 18600    |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 93000    |
# | train/                |          |
# |    entropy_loss       | -0.305   |
# |    explained_variance | 0.725    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18599    |
# |    policy_loss        | -0.446   |
# |    value_loss         | 1.41     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 295      |
# |    ep_rew_mean        | 14.3     |
# | time/                 |          |
# |    fps                | 3221     |
# |    iterations         | 18700    |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 93500    |
# | train/                |          |
# |    entropy_loss       | -0.413   |
# |    explained_variance | 0.899    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18699    |
# |    policy_loss        | -2.76    |
# |    value_loss         | 17       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 295      |
# |    ep_rew_mean        | 14.3     |
# | time/                 |          |
# |    fps                | 3221     |
# |    iterations         | 18800    |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.646   |
# |    explained_variance | 0.976    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18799    |
# |    policy_loss        | 0.24     |
# |    value_loss         | 0.231    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 302      |
# |    ep_rew_mean        | 10.6     |
# | time/                 |          |
# |    fps                | 3221     |
# |    iterations         | 18900    |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 94500    |
# | train/                |          |
# |    entropy_loss       | -0.106   |
# |    explained_variance | 0.884    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18899    |
# |    policy_loss        | 0.623    |
# |    value_loss         | 0.491    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 301      |
# |    ep_rew_mean        | 10.1     |
# | time/                 |          |
# |    fps                | 3221     |
# |    iterations         | 19000    |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 95000    |
# | train/                |          |
# |    entropy_loss       | -0.54    |
# |    explained_variance | 0.922    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18999    |
# |    policy_loss        | -0.453   |
# |    value_loss         | 2.39     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 303      |
# |    ep_rew_mean        | 9.65     |
# | time/                 |          |
# |    fps                | 3221     |
# |    iterations         | 19100    |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 95500    |
# | train/                |          |
# |    entropy_loss       | -0.423   |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19099    |
# |    policy_loss        | 0.0296   |
# |    value_loss         | 0.274    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 306      |
# |    ep_rew_mean        | 10.9     |
# | time/                 |          |
# |    fps                | 3221     |
# |    iterations         | 19200    |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.377   |
# |    explained_variance | 0.491    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19199    |
# |    policy_loss        | -0.877   |
# |    value_loss         | 1.61     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 306      |
# |    ep_rew_mean        | 10.9     |
# | time/                 |          |
# |    fps                | 3221     |
# |    iterations         | 19300    |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 96500    |
# | train/                |          |
# |    entropy_loss       | -0.853   |
# |    explained_variance | 0.615    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19299    |
# |    policy_loss        | -1.18    |
# |    value_loss         | 1.79     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 313      |
# |    ep_rew_mean        | 7.13     |
# | time/                 |          |
# |    fps                | 3222     |
# |    iterations         | 19400    |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 97000    |
# | train/                |          |
# |    entropy_loss       | -0.807   |
# |    explained_variance | 0.0664   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19399    |
# |    policy_loss        | -2.01    |
# |    value_loss         | 19.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 313      |
# |    ep_rew_mean        | 7.13     |
# | time/                 |          |
# |    fps                | 3222     |
# |    iterations         | 19500    |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 97500    |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | 0.841    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19499    |
# |    policy_loss        | -0.51    |
# |    value_loss         | 0.329    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 318      |
# |    ep_rew_mean        | 5.08     |
# | time/                 |          |
# |    fps                | 3222     |
# |    iterations         | 19600    |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.482   |
# |    explained_variance | 0.661    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19599    |
# |    policy_loss        | 1.69     |
# |    value_loss         | 18.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 319      |
# |    ep_rew_mean        | 8.9      |
# | time/                 |          |
# |    fps                | 3220     |
# |    iterations         | 19700    |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 98500    |
# | train/                |          |
# |    entropy_loss       | -0.528   |
# |    explained_variance | 0.937    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19699    |
# |    policy_loss        | -1.62    |
# |    value_loss         | 0.87     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 319      |
# |    ep_rew_mean        | 8.9      |
# | time/                 |          |
# |    fps                | 3219     |
# |    iterations         | 19800    |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 99000    |
# | train/                |          |
# |    entropy_loss       | -0.887   |
# |    explained_variance | 0.244    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19799    |
# |    policy_loss        | -0.655   |
# |    value_loss         | 3.7      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 324      |
# |    ep_rew_mean        | 7.47     |
# | time/                 |          |
# |    fps                | 3220     |
# |    iterations         | 19900    |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 99500    |
# | train/                |          |
# |    entropy_loss       | -0.666   |
# |    explained_variance | -1.85    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19899    |
# |    policy_loss        | 2        |
# |    value_loss         | 7.72     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 324      |
# |    ep_rew_mean        | 7.47     |
# | time/                 |          |
# |    fps                | 3220     |
# |    iterations         | 20000    |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.32    |
# |    explained_variance | 0.739    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19999    |
# |    policy_loss        | -0.12    |
# |    value_loss         | 1.43     |
# ------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/jozaita/Documents/Stable_baselines_tutorial/yt_tutorials/sentdex_1.ipynb Celda 4 line 1
#       <a href='vscode-notebook-cell:/Users/jozaita/Documents/Stable_baselines_tutorial/yt_tutorials/sentdex_1.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a>     done = False
#      <a href='vscode-notebook-cell:/Users/jozaita/Documents/Stable_baselines_tutorial/yt_tutorials/sentdex_1.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a>     while not done:
# ---> <a href='vscode-notebook-cell:/Users/jozaita/Documents/Stable_baselines_tutorial/yt_tutorials/sentdex_1.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a>         env.render("human")
#      <a href='vscode-notebook-cell:/Users/jozaita/Documents/Stable_baselines_tutorial/yt_tutorials/sentdex_1.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a>         obs,reward,done,truncated,info = env.step(env.action_space.sample())
#      <a href='vscode-notebook-cell:/Users/jozaita/Documents/Stable_baselines_tutorial/yt_tutorials/sentdex_1.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a> env.close()
#
# TypeError: Wrapper.render() takes 1 positional argument but 2 were given
